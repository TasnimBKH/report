# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver import ActionChains
import openpyxl
import os
import os.path
import asyncio

pdf_folder_path="C:\\Users\\rafiquel.islam\\Desktop\\Report File"
website_path="http://192.168.20.159/FinUltimusSPARKTEST/"
driver_link="E:\Software\chromedriver.exe"
input_output_path="E:selenium//result.xlsx"




options = webdriver.ChromeOptions()
options.add_experimental_option('prefs', {"download.default_directory":pdf_folder_path ,  #Change default directory for downloads
"download.prompt_for_download": False, #To auto download the file
"download.directory_upgrade": True,
"plugins.always_open_pdf_externally": True #It will not show PDF directly in chrome
})


driver = webdriver.Chrome(executable_path=driver_link,options=options)
driver.get(website_path)
user_ele=driver.find_element_by_name("UserId")

pass_ele=driver.find_element_by_name("PasswordString")

user_ele.send_keys("s1")
pass_ele.send_keys("1")
pass_ele=driver.find_element_by_name("PasswordString")
driver.find_element_by_id("btnlogin").click()

drp=Select(driver.find_element_by_name("ctl00$ddlMenutype"))
#driver.find_element_by_value("R").click()
drp.select_by_value("R")


#v_search2=[9309,9302,9309,9830]
df=openpyxl.load_workbook(input_output_path)
sheet=df.active
v_search2=[]
df1=df['result']
df2=df['perameter']
for i in range(1,df1.max_row+1):
    j=df1.cell(row=i,column=1)
    v_search2.append(j.value)
print(v_search2)


for x in range(len(v_search2)):
    driver.find_element_by_id("txtMenuSearch").clear()
    ser_ele=driver.find_element_by_id("txtMenuSearch")
    k=v_search2[x]
    print(k)  
    ser_ele.send_keys(k)
    ser_ele.send_keys(Keys.ENTER)
    
    table=driver.find_elements_by_tag_name('h1')
    print(len(table))
    print("")
    if(len(table)==0):
        #print("welcome")
        for i in range(2,df2.max_row+1):
            
            c=df2.cell(row=i,column=1)
            #print(i,1)
            if c.value==k:
                
                #print('ok')
                d=df2.cell(row=i,column=4)
                id_tag=df2.cell(row=i,column=3)
                e=df2.cell(row=i,column=5)
                    
                if id_tag.value=='Id':
                    
                    #print("hello")
                    acc_ele=driver.find_element_by_id(d.value)
                    acc_ele.send_keys(e.value)
                elif id_tag.value=='name':
                    acc_ele=driver.find_element_by_name(d.value)
                    acc_ele.send_keys(e.value)
                        
                        
      #  time.sleep(2)
        ok_ele=driver.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()
     
        action = ActionChains(driver)
 
        #perform the operation
        action.key_down(Keys.ALT).send_keys('O').perform()
       
        #ok button work...............
       
        #print(driver.window_handles[0])
       
       
       
        window_after = driver.window_handles[1]
        #print(window_after)
        driver.switch_to.window(window_after)
        
        
        #print(window_after)
   
        suc_ele=driver.find_elements_by_tag_name('body')
        fal_ele=driver.find_elements_by_tag_name('form')
            

        print(k)
        for i in range(1,df1.max_row+1):
            for j in range(1,2):
               
                if(df1.cell(i,j).value==k ):
                 
                    if len(fal_ele)==0:
                    
                        df1.cell(i,j+1).value="ok"
                       
                    else:
                        
                        df1.cell(i,j+1).value="Failed"
      
        df.save(path)
        
    
        #file_exist=os.path.exists('C:\\Users\\rafiquel.islam\\Desktop\\Report File\\BU_ReportPreviewPOPUPUI.pdf')
        #await asyncio.sleep(5) 
        #if(file_exist==True):
            #time.sleep(1) 
           # os.rename("C:\\Users\\rafiquel.islam\\Desktop\\Report File\\BU_ReportPreviewPOPUPUI.pdf",
                      #  "C:\\Users\\rafiquel.islam\\Desktop\\Report File\\"+str(k)+".pdf")
          #  await asyncio.sleep(3)
        #time.sleep(0.5)   
        #print(file_exist)
        driver.close()
       
        window_before = driver.window_handles[0]
        driver.switch_to.window(window_before)
        #time.sleep(0.2) 
             
             
    else:
        for i in range(1,df1.max_row+1):
            for j in range(1,2):
               
                if(df1.cell(i,j).value==k ):
                     df1.cell(i,j+1).value="Unauthorized"
        df.save(path)       
                    
        continue
# Out:
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_10004\971786608.py:27: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=driver_link,options=options)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [2], in <cell line: 27>()
#      19 options = webdriver.ChromeOptions()
#      20 options.add_experimental_option('prefs', {"download.default_directory":pdf_folder_path ,  #Change default directory for downloads
#      21 "download.prompt_for_download": False, #To auto download the file
#      22 "download.directory_upgrade": True,
#      23 "plugins.always_open_pdf_externally": True #It will not show PDF directly in chrome
#      24 })
# ---> 27 driver = webdriver.Chrome(executable_path=driver_link,options=options)
#      28 driver.get(website_path)
#      29 user_ele=driver.find_element_by_name("UserId")
#
# File E:\Software\lib\site-packages\selenium\webdriver\chrome\webdriver.py:70, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67 if not service:
#      68     service = Service(executable_path, port, service_args, service_log_path)
# ---> 70 super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                 port, options,
#      72                                 service_args, desired_capabilities,
#      73                                 service_log_path, service, keep_alive)
#
# File E:\Software\lib\site-packages\selenium\webdriver\chromium\webdriver.py:92, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      89 self.service.start()
#      91 try:
# ---> 92     RemoteWebDriver.__init__(
#      93         self,
#      94         command_executor=ChromiumRemoteConnection(
#      95             remote_server_addr=self.service.service_url,
#      96             browser_name=browser_name, vendor_prefix=vendor_prefix,
#      97             keep_alive=keep_alive, ignore_proxy=_ignore_proxy),
#      98         options=options)
#      99 except Exception:
#     100     self.quit()
#
# File E:\Software\lib\site-packages\selenium\webdriver\remote\webdriver.py:275, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     273 self._authenticator_id = None
#     274 self.start_client()
# --> 275 self.start_session(capabilities, browser_profile)
#
# File E:\Software\lib\site-packages\selenium\webdriver\remote\webdriver.py:365, in WebDriver.start_session(self, capabilities, browser_profile)
#     363 w3c_caps = _make_w3c_caps(capabilities)
#     364 parameters = {"capabilities": w3c_caps}
# --> 365 response = self.execute(Command.NEW_SESSION, parameters)
#     366 if 'sessionId' not in response:
#     367     response = response['value']
#
# File E:\Software\lib\site-packages\selenium\webdriver\remote\webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File E:\Software\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: Chrome failed to start: exited normally.
#   (chrome not reachable)
#   (The process started from chrome location C:\Program Files\Google\Chrome\Application\chrome.exe is no longer running, so ChromeDriver is assuming that Chrome has crashed.)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0091D953+2414931]
# 	Ordinal0 [0x008AF5E1+1963489]
# 	Ordinal0 [0x0079C6B8+837304]
# 	Ordinal0 [0x007B9BD4+957396]
# 	Ordinal0 [0x007B5FB1+942001]
# 	Ordinal0 [0x007E9100+1151232]
# 	Ordinal0 [0x007E8D5A+1150298]
# 	Ordinal0 [0x007E42B6+1131190]
# 	Ordinal0 [0x007BE860+976992]
# 	Ordinal0 [0x007BF756+980822]
# 	GetHandleVerifier [0x00B8CC62+2510274]
# 	GetHandleVerifier [0x00B7F760+2455744]
# 	GetHandleVerifier [0x009AEABA+551962]
# 	GetHandleVerifier [0x009AD916+547446]
# 	Ordinal0 [0x008B5F3B+1990459]
# 	Ordinal0 [0x008BA898+2009240]
# 	Ordinal0 [0x008BA985+2009477]
# 	Ordinal0 [0x008C3AD1+2046673]
# 	BaseThreadInitThunk [0x764FFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CF7A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CF7A4E+238]

# %% [markdown]
# # function declaration for input list

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver import ActionChains
import openpyxl
import os
import os.path
import asyncio

pdf_folder_path="C:\\Users\\rafiquel.islam\\Desktop\\Report File"
website_path="http://192.168.20.159/FinUltimusSPARKTEST/"
driver_link="E:\Software\chromedriver.exe"
input_output_path="E:selenium//result.xlsx"

df=openpyxl.load_workbook(input_output_path)
sheet=df.active
fastPathSearch=[]
resultsheet=df['result']
perametersheet=df['perameter']

#driver = webdriver.Chrome(executable_path=driver_link,options=options)
#driver.get(website_path)

def main():
    options = webdriver.ChromeOptions()
    options.add_experimental_option('prefs', {"download.default_directory":pdf_folder_path ,  #Change default directory for downloads
    "download.prompt_for_download": False, #To auto download the file
    "download.directory_upgrade": True,
    "plugins.always_open_pdf_externally": True #It will not show PDF directly in chrome
                                            
    })
    driver=login("s1",1)
    driver1=driver
    fastPathSearch=input_list()
    print(fastPathSearch)
    loop_for_every_path(driver1,fastPathSearch)
def login(username,password):

    
    driver = webdriver.Chrome(executable_path=driver_link)
    driver.get(website_path)
    user_ele=driver.find_element_by_name("UserId")

    pass_ele=driver.find_element_by_name("PasswordString")

    user_ele.send_keys(username)
    pass_ele.send_keys(password)
    driver.find_element_by_id("btnlogin").click()
    drp=Select(driver.find_element_by_name("ctl00$ddlMenutype"))
    #print(driver)
    drp.select_by_value("R")
    #time.sleep(5)
    return driver
   
    
def input_list():
    for i in range(1,resultsheet.max_row+1):
        j=resultsheet.cell(row=i,column=1)
        fastPathSearch.append(j.value)
    return fastPathSearch
def loop_for_every_path(driver,fastPathSearch):
    #driver=login("s1",1)
    driver1=driver
    fastPathSearch=input_list()
    for x in range(len(fastPathSearch)):
        driver1.find_element_by_id("txtMenuSearch").clear()
        ser_ele=driver1.find_element_by_id("txtMenuSearch")
        fastPathId=fastPathSearch[x]
        print(fastPathId)  
        ser_ele.send_keys(fastPathId)
        ser_ele.send_keys(Keys.ENTER)
        table=driver1.find_elements_by_tag_name('h1')
        print(len(table))
        if(len(table)==0):
            checkauthorization(fastPathId,driver,perametersheet)
        else:
            checkunauthorized(fastPathId,resultsheet,input_output_path)
        #return fastPathId    
            
def checkauthorization(fastPathId,driver,perametersheet):
    for i in range(2,perametersheet.max_row+1):
        
        c=perametersheet.cell(row=i,column=1)
        if c.value==fastPathId:
          
            d=perametersheet.cell(row=i,column=4)
            id_tag=perametersheet.cell(row=i,column=3)
            e=perametersheet.cell(row=i,column=5)
            if id_tag.value=='Id':
                acc_ele=driver.find_element_by_id(d.value)
                acc_ele.send_keys(e.value)
            elif id_tag.value=='name':
                acc_ele=driver.find_element_by_name(d.value)
                acc_ele.send_keys(e.value)
    
    ok_ele=driver.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()

    action = ActionChains(driver)
   
    action.key_down(Keys.ALT).send_keys('O').perform() 
    window_after = driver.window_handles[1]
  
    driver.switch_to.window(window_after)

 
    fal_ele=driver.find_elements_by_tag_name('form')

    for i in range(1,resultsheet.max_row+1):
        for j in range(1,2):
            if(resultsheet.cell(i,j).value==fastPathId ):
                if len(fal_ele)==0:
                    resultsheet.cell(i,j+1).value="ok"
                else:
                    resultsheet.cell(i,j+1).value="Failed"

            df.save(input_output_path)
    driver.close()
    window_before = driver.window_handles[0]
    driver.switch_to.window(window_before)
      
def checkunauthorized(fastPathId,resultsheet,input_output_path):
    for i in range(1,resultsheet.max_row+1):
        
        for j in range(1,2):
            
            if(resultsheet.cell(i,j).value==fastPathId ):
                resultsheet.cell(i,j+1).value="Unauthorized"
                df.save(input_output_path)  
            continue
            
main()
# Out:
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3649577273.py:41: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=driver_link)
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3649577273.py:43: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   user_ele=driver.find_element_by_name("UserId")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3649577273.py:45: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   pass_ele=driver.find_element_by_name("PasswordString")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3649577273.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("btnlogin").click()
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3649577273.py:50: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   drp=Select(driver.find_element_by_name("ctl00$ddlMenutype"))
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3649577273.py:67: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver1.find_element_by_id("txtMenuSearch").clear()
# [9802, 9803, 9804, 9800]
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3649577273.py:68: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ser_ele=driver1.find_element_by_id("txtMenuSearch")
# 9802
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3649577273.py:73: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   table=driver1.find_elements_by_tag_name('h1')
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3649577273.py:97: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   ok_ele=driver.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()
# 0
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3649577273.py:107: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   fal_ele=driver.find_elements_by_tag_name('form')
# 9803
# 0
# 9804
# 0
# 9800
# 1
# 9802
# 0
# 9803
# 0
# 9804
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [26], in <cell line: 132>()
#     129                 df.save(input_output_path)
#     130             continue
# --> 132 main()
#
# Input In [26], in main()
#      35 fastPathSearch=input_list()
#      36 print(fastPathSearch)
# ---> 37 loop_for_every_path(driver1,fastPathSearch)
#
# Input In [26], in loop_for_every_path(driver, fastPathSearch)
#      74 print(len(table))
#      75 if(len(table)==0):
# ---> 76     checkauthorization(fastPathId,driver,perametersheet)
#      77 else:
#      78     checkunauthorized(fastPathId,resultsheet,input_output_path)
#
# Input In [26], in checkauthorization(fastPathId, driver, perametersheet)
#      99 action = ActionChains(driver)
#     101 action.key_down(Keys.ALT).send_keys('O').perform()
# --> 102 window_after = driver.window_handles[1]
#     104 driver.switch_to.window(window_after)
#     107 fal_ele=driver.find_elements_by_tag_name('form')
#
# IndexError: list index out of range

# %% [markdown]
# # Search element function

# %%
def main():
    print("Hello World!")

if __name__ == "__main__":
    main()
# Out:
# Hello World!

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver import ActionChains
import openpyxl
import os
import os.path
import asyncio

pdf_folder_path="C:\\Users\\rafiquel.islam\\Desktop\\Report File"
website_path="http://192.168.20.159/FinUltimusSPARKTEST/"
driver_link="E:\Software\chromedriver.exe"
input_output_path="E:selenium//result.xlsx"

df=openpyxl.load_workbook(input_output_path)
sheet=df.active
fastPathSearch=[]
resultsheet=df['result']
perametersheet=df['perameter']

#driver = webdriver.Chrome(executable_path=driver_link,options=options)
#driver.get(website_path)

def main():
    options = webdriver.ChromeOptions()
    options.add_experimental_option('prefs', {"download.default_directory":pdf_folder_path ,  #Change default directory for downloads
    "download.prompt_for_download": False, #To auto download the file
    "download.directory_upgrade": True,
    "plugins.always_open_pdf_externally": True #It will not show PDF directly in chrome
                                            
    })
    driver=login("s1",1)
    driver1=driver
    fastPathSearch=input_list()
    print(fastPathSearch)
    fastPathId=loop_for_every_path(driver1,fastPathSearch)
    search_path(fastPathId,driver)
  
    """
    for x in range(len(fastPathSearch)):
        driver1.find_element_by_id("txtMenuSearch").clear()
        ser_ele=driver1.find_element_by_id("txtMenuSearch")
        k=fastPathSearch[x]
        print(k)  
        ser_ele.send_keys(k)
        ser_ele.send_keys(Keys.ENTER)
        table=driver1.find_elements_by_tag_name('h1')
        print(len(table))
        if(len(table)==0):
            #print("welcome")
            for i in range(2,perametersheet.max_row+1):

                c=perametersheet.cell(row=i,column=1)
                #print(i,1)
                if c.value==k:

                    #print('ok')
                    d=perametersheet.cell(row=i,column=4)
                    id_tag=perametersheet.cell(row=i,column=3)
                    e=perametersheet.cell(row=i,column=5)

                    if id_tag.value=='Id':

                        #print("hello")
                        acc_ele=driver.find_element_by_id(d.value)
                        acc_ele.send_keys(e.value)
                    elif id_tag.value=='name':
                        acc_ele=driver.find_element_by_name(d.value)
                        acc_ele.send_keys(e.value)


          #  time.sleep(2)
            ok_ele=driver1.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()

            action = ActionChains(driver)

            #perform the operation
            action.key_down(Keys.ALT).send_keys('O').perform()
            
            window_after = driver1.window_handles[1]
            #print(window_after)
            driver.switch_to.window(window_after)


            #print(window_after)

            suc_ele=driver.find_elements_by_tag_name('body')
            fal_ele=driver.find_elements_by_tag_name('form')

            for i in range(1,resultsheet.max_row+1):
                for j in range(1,2):

                    if(resultsheet.cell(i,j).value==k ):

                        if len(fal_ele)==0:

                            resultsheet.cell(i,j+1).value="ok"

                        else:

                            resultsheet.cell(i,j+1).value="Failed"

            df.save(input_output_path)


            #file_exist=os.path.exists('C:\\Users\\rafiquel.islam\\Desktop\\Report File\\BU_ReportPreviewPOPUPUI.pdf')
            #await asyncio.sleep(5) 
            #if(file_exist==True):
                #time.sleep(1) 
               # os.rename("C:\\Users\\rafiquel.islam\\Desktop\\Report File\\BU_ReportPreviewPOPUPUI.pdf",
                          #  "C:\\Users\\rafiquel.islam\\Desktop\\Report File\\"+str(k)+".pdf")
              #  await asyncio.sleep(3)
            #time.sleep(0.5)   
            #print(file_exist)
            driver.close()

            window_before = driver.window_handles[0]
            driver.switch_to.window(window_before)
            #time.sleep(0.2) 
#resultsheet=df['result']
#perametersheet=df['perameter']

        else:
            for i in range(1,resultsheet.max_row+1):
                for j in range(1,2):

                    if(resultsheet.cell(i,j).value==k ):
                         resultsheet.cell(i,j+1).value="Unauthorized"
            df.save(input_output_path)       

            continue

"""
    

def login(username,password):

    
    driver = webdriver.Chrome(executable_path=driver_link)
    driver.get(website_path)
    user_ele=driver.find_element_by_name("UserId")

    pass_ele=driver.find_element_by_name("PasswordString")

    user_ele.send_keys(username)
    pass_ele.send_keys(password)
    driver.find_element_by_id("btnlogin").click()
    drp=Select(driver.find_element_by_name("ctl00$ddlMenutype"))
    #print(driver)
    drp.select_by_value("R")
    #time.sleep(5)
    return driver
   
    
def input_list():
    for i in range(1,resultsheet.max_row+1):
        j=resultsheet.cell(row=i,column=1)
        fastPathSearch.append(j.value)
    return fastPathSearch
def loop_for_every_path(driver,fastPathSearch):
    #driver=login("s1",1)
    driver1=driver
    fastPathSearch=input_list()
    for x in range(len(fastPathSearch)):
        driver1.find_element_by_id("txtMenuSearch").clear()
        ser_ele=driver1.find_element_by_id("txtMenuSearch")
        fastPathId=fastPathSearch[x]
        ser_ele.send_keys(fastPathId)
        ser_ele.send_keys(Keys.ENTER)
        print(fastPathId)
        search_path(fastPathId,driver)
    return fastPathId
def search_path(fastPathId,driver):
    
    unauthorized=driver.find_elements_by_tag_name('h1')
    print(len(unauthorized))
    if(len(unauthorized)==0):
        checkauthorization(fastPathId,driver,perametersheet)
        change_window(driver)
    else:
        checkunauthorized(fastPathId,resultsheet,input_output_path)
        #return fastPathId 
    #return fastPathId 
    
    
        
            
def checkauthorization(fastPathId,driver,perametersheet):
    for i in range(2,perametersheet.max_row+1):
        
        c=perametersheet.cell(row=i,column=1)
        if c.value==fastPathId:
          
            d=perametersheet.cell(row=i,column=4)
            id_tag=perametersheet.cell(row=i,column=3)
            e=perametersheet.cell(row=i,column=5)
            if id_tag.value=='Id':
                acc_ele=driver.find_element_by_id(d.value)
                acc_ele.send_keys(e.value)
            elif id_tag.value=='name':
                acc_ele=driver.find_element_by_name(d.value)
                acc_ele.send_keys(e.value)
    result(fastPathId,driver,resultsheet)
    change_window(driver)
    
def result(fastPathId,driver,resultsheet):
    
    ok_ele=driver.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()

    action = ActionChains(driver)
    #perform the operation
    action.key_down(Keys.ALT).send_keys('O').perform()
    
    
def change_window(driver):
    
    
    window_after = driver.window_handles[1]
    #print(window_after)
    driver.switch_to.window(window_after)
    fal_ele=driver.find_elements_by_tag_name('form')

    for i in range(1,resultsheet.max_row+1):
        for j in range(1,2):
            if(resultsheet.cell(i,j).value==fastPathId ):
                if len(fal_ele)==0:
                    resultsheet.cell(i,j+1).value="ok"
                else:
                    resultsheet.cell(i,j+1).value="Failed"

            df.save(input_output_path)
    driver.close()
    window_before = driver.window_handles[0]
    driver.switch_to.window(window_before)


    

        
def checkunauthorized(fastPathId,resultsheet,input_output_path):
    for i in range(1,resultsheet.max_row+1):
        
        for j in range(1,2):
            
            if(resultsheet.cell(i,j).value==fastPathId ):
                resultsheet.cell(i,j+1).value="Unauthorized"
                df.save(input_output_path)  
            continue
            
main()
# Out:
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3274493710.py:140: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=driver_link)
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3274493710.py:142: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   user_ele=driver.find_element_by_name("UserId")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3274493710.py:144: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   pass_ele=driver.find_element_by_name("PasswordString")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3274493710.py:148: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("btnlogin").click()
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3274493710.py:149: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   drp=Select(driver.find_element_by_name("ctl00$ddlMenutype"))
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3274493710.py:166: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver1.find_element_by_id("txtMenuSearch").clear()
# [9802, 9803, 9804, 9800]
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3274493710.py:167: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ser_ele=driver1.find_element_by_id("txtMenuSearch")
# 9802
# 0
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3274493710.py:176: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   unauthorized=driver.find_elements_by_tag_name('h1')
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3274493710.py:209: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   ok_ele=driver.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_5368\3274493710.py:222: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   fal_ele=driver.find_elements_by_tag_name('form')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 251>()
#     248                 df.save(input_output_path)
#     249             continue
# --> 251 main()
#
# Input In [19], in main()
#      35     fastPathSearch=input_list()
#      36     print(fastPathSearch)
# ---> 37     fastPathId=loop_for_every_path(driver1,fastPathSearch)
#      38     search_path(fastPathId,driver)
#      40     """
#      41     for x in range(len(fastPathSearch)):
#      42         driver1.find_element_by_id("txtMenuSearch").clear()
#    (...)
#     133
#     134 """
#
# Input In [19], in loop_for_every_path(driver, fastPathSearch)
#     170     ser_ele.send_keys(Keys.ENTER)
#     171     print(fastPathId)
# --> 172     search_path(fastPathId,driver)
#     173 return fastPathId
#
# Input In [19], in search_path(fastPathId, driver)
#     177 print(len(unauthorized))
#     178 if(len(unauthorized)==0):
# --> 179     checkauthorization(fastPathId,driver,perametersheet)
#     180     change_window(driver)
#     181 else:
#
# Input In [19], in checkauthorization(fastPathId, driver, perametersheet)
#     203             acc_ele.send_keys(e.value)
#     204 result(fastPathId,driver,resultsheet)
# --> 205 change_window(driver)
#
# Input In [19], in change_window(driver)
#     224 for i in range(1,resultsheet.max_row+1):
#     225     for j in range(1,2):
# --> 226         if(resultsheet.cell(i,j).value==fastPathId ):
#     227             if len(fal_ele)==0:
#     228                 resultsheet.cell(i,j+1).value="ok"
#
# NameError: name 'fastPathId' is not defined
