# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver import ActionChains
import openpyxl
import os
import os.path


options = webdriver.ChromeOptions()
options.add_experimental_option('prefs', {"download.default_directory": "C:\\Users\\rafiquel.islam\\Desktop\\Report File",                                         #Change default directory for downloads
"download.prompt_for_download": False, #To auto download the file
"download.directory_upgrade": True,
"plugins.always_open_pdf_externally": True #It will not show PDF directly in chrome
})


driver = webdriver.Chrome(executable_path="E:\Software\chromedriver.exe",options=options)
driver.get("http://192.168.20.159/FinUltimusSPARKTEST/")
user_ele=driver.find_element_by_name("UserId")

pass_ele=driver.find_element_by_name("PasswordString")

user_ele.send_keys("s1")
pass_ele.send_keys("1")
pass_ele=driver.find_element_by_name("PasswordString")
driver.find_element_by_id("btnlogin").click()

drp=Select(driver.find_element_by_name("ctl00$ddlMenutype"))
#driver.find_element_by_value("R").click()
drp.select_by_value("R")


#v_search2=[9309,9302,9309,9830]
path="E:selenium//result.xlsx"
df=openpyxl.load_workbook(path)
sheet=df.active
v_search2=[]
df1=df['result']
df2=df['perameter']
for i in range(1,df1.max_row+1):
    j=df1.cell(row=i,column=1)
    v_search2.append(j.value)
print(v_search2)


for x in range(len(v_search2)):
    driver.find_element_by_id("txtMenuSearch").clear()
    ser_ele=driver.find_element_by_id("txtMenuSearch")
    k=v_search2[x]
    print(k)  
    ser_ele.send_keys(k)
    ser_ele.send_keys(Keys.ENTER)
    
    table=driver.find_elements_by_tag_name('h1')
    print(len(table))
    print("")
    if(len(table)==0):
        #print("welcome")
        for i in range(2,df2.max_row+1):
            
            c=df2.cell(row=i,column=1)
            #print(i,1)
            if c.value==k:
                
                #print('ok')
                d=df2.cell(row=i,column=4)
                id_tag=df2.cell(row=i,column=3)
                e=df2.cell(row=i,column=5)
                    
                if id_tag.value=='Id':
                    
                    #print("hello")
                    acc_ele=driver.find_element_by_id(d.value)
                    acc_ele.send_keys(e.value)
                elif id_tag.value=='name':
                    acc_ele=driver.find_element_by_name(d.value)
                    acc_ele.send_keys(e.value)
                        
                        
         
        ok_ele=driver.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()
     
        action = ActionChains(driver)
 
        #perform the operation
        action.key_down(Keys.ALT).send_keys('O').perform()
       
        #ok button work...............
       
        #print(driver.window_handles[0])
       
       
       
        window_after = driver.window_handles[1]
        #print(window_after)
        driver.switch_to.window(window_after)
        
        
        #print(window_after)
   
        suc_ele=driver.find_elements_by_tag_name('body')
        fal_ele=driver.find_elements_by_tag_name('form')
            

        print(k)
        for i in range(1,df1.max_row+1):
            for j in range(1,2):
               
                if(df1.cell(i,j).value==k ):
                 
                    if len(fal_ele)==0:
                    
                        df1.cell(i,j+1).value="ok"
                       
                    else:
                        
                        df1.cell(i,j+1).value="Failed"
      
        df.save(path)
        driver.close()
    
        file_exist=os.path.exists('C:\\Users\\rafiquel.islam\\Desktop\\Report File\\BU_ReportPreviewPOPUPUI.pdf')
        if(file_exist==True):
            os.rename("C:\\Users\\rafiquel.islam\\Desktop\\Report File\\BU_ReportPreviewPOPUPUI.pdf",
                        "C:\\Users\\rafiquel.islam\\Desktop\\Report File\\"+str(k)+".pdf")
            
        print(file_exist)
       
        window_before = driver.window_handles[0]
        driver.switch_to.window(window_before)
             
             
    else:
        for i in range(1,df1.max_row+1):
            for j in range(1,2):
               
                if(df1.cell(i,j).value==k ):
                     df1.cell(i,j+1).value="Unauthorized"
        df.save(path)       
                    
        continue
# Out:
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:19: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="E:\Software\chromedriver.exe",options=options)
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:21: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   user_ele=driver.find_element_by_name("UserId")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:23: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   pass_ele=driver.find_element_by_name("PasswordString")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:27: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   pass_ele=driver.find_element_by_name("PasswordString")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("btnlogin").click()
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:30: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   drp=Select(driver.find_element_by_name("ctl00$ddlMenutype"))
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:49: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("txtMenuSearch").clear()
# [9842, 9843, 9844, 9845, 9846, 9847]
# 9842
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:50: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ser_ele=driver.find_element_by_id("txtMenuSearch")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:56: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   table=driver.find_elements_by_tag_name('h1')
# 1
#
# 9843
# 1
#
# 9844
# 0
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:83: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   ok_ele=driver.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:103: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   suc_ele=driver.find_elements_by_tag_name('body')
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:104: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   fal_ele=driver.find_elements_by_tag_name('form')
# 9844
# True
# 9845
# 0
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\2380049130.py:78: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   acc_ele=driver.find_element_by_name(d.value)
# 9845
# True
# 9846
# 0
#
# 9846
# True
# 9847
# 0
#
# 9847
# True

# %% [markdown]
# # Give Valid variable Name

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver import ActionChains
import openpyxl
import os
import os.path


options = webdriver.ChromeOptions()
options.add_experimental_option('prefs', {"download.default_directory": "C:\\Users\\rafiquel.islam\\Desktop\\Report File",                                         #Change default directory for downloads
"download.prompt_for_download": False, #To auto download the file
"download.directory_upgrade": True,
"plugins.always_open_pdf_externally": True #It will not show PDF directly in chrome
})


driver = webdriver.Chrome(executable_path="E:\Software\chromedriver.exe",options=options)
driver.get("http://192.168.20.159/FinUltimusSPARKTEST/")
user_ele=driver.find_element_by_name("UserId")

pass_ele=driver.find_element_by_name("PasswordString")

user_ele.send_keys("s1")
pass_ele.send_keys("1")
pass_ele=driver.find_element_by_name("PasswordString")
driver.find_element_by_id("btnlogin").click()

drp=Select(driver.find_element_by_name("ctl00$ddlMenutype"))
#driver.find_element_by_value("R").click()
drp.select_by_value("R")


#v_search2=[9309,9302,9309,9830]
path="E:selenium//result.xlsx"
df=openpyxl.load_workbook(path)
sheet=df.active
v_search2=[]
df1=df['result']
df2=df['perameter']
for i in range(1,df1.max_row+1):
    j=df1.cell(row=i,column=1)
    v_search2.append(j.value)
print(v_search2)


for x in range(len(v_search2)):
    driver.find_element_by_id("txtMenuSearch").clear()
    ser_ele=driver.find_element_by_id("txtMenuSearch")
    k=v_search2[x]
    print(k)  
    ser_ele.send_keys(k)
    ser_ele.send_keys(Keys.ENTER)
    
    table=driver.find_elements_by_tag_name('h1')
    print(len(table))
    print("")
    if(len(table)==0):
        #print("welcome")
        for i in range(2,df2.max_row+1):
            
            c=df2.cell(row=i,column=1)
            #print(i,1)
            if c.value==k:
                
                #print('ok')
                d=df2.cell(row=i,column=4)
                id_tag=df2.cell(row=i,column=3)
                e=df2.cell(row=i,column=5)
                    
                if id_tag.value=='Id':
                    
                    #print("hello")
                    acc_ele=driver.find_element_by_id(d.value)
                    acc_ele.send_keys(e.value)
                elif id_tag.value=='name':
                    acc_ele=driver.find_element_by_name(d.value)
                    acc_ele.send_keys(e.value)
                        
                        
         
        ok_ele=driver.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()
     
        action = ActionChains(driver)
 
        #perform the operation
        action.key_down(Keys.ALT).send_keys('O').perform()
       
        #ok button work...............
       
        #print(driver.window_handles[0])
       
       
       
        window_after = driver.window_handles[1]
        #print(window_after)
        driver.switch_to.window(window_after)
        
        
        #print(window_after)
   
        suc_ele=driver.find_elements_by_tag_name('body')
        fal_ele=driver.find_elements_by_tag_name('form')
            

        print(k)
        for i in range(1,df1.max_row+1):
            for j in range(1,2):
               
                if(df1.cell(i,j).value==k ):
                 
                    if len(fal_ele)==0:
                    
                        df1.cell(i,j+1).value="ok"
                       
                    else:
                        
                        df1.cell(i,j+1).value="Failed"
      
        df.save(path)
        driver.close()
    
        file_exist=os.path.exists('C:\\Users\\rafiquel.islam\\Desktop\\Report File\\BU_ReportPreviewPOPUPUI.pdf')
        if(file_exist==True):
            os.rename("C:\\Users\\rafiquel.islam\\Desktop\\Report File\\BU_ReportPreviewPOPUPUI.pdf",
                        "C:\\Users\\rafiquel.islam\\Desktop\\Report File\\"+str(k)+".pdf")
            
        print(file_exist)
       
        window_before = driver.window_handles[0]
        driver.switch_to.window(window_before)
             
             
    else:
        for i in range(1,df1.max_row+1):
            for j in range(1,2):
               
                if(df1.cell(i,j).value==k ):
                     df1.cell(i,j+1).value="Unauthorized"
        df.save(path)       
                    
        continue

# %% [markdown]
# # Create function

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver import ActionChains
import openpyxl
import os
import os.path
import asyncio


options = webdriver.ChromeOptions()
options.add_experimental_option('prefs', {"download.default_directory": "C:\\Users\\rafiquel.islam\\Desktop\\Report File",                                         #Change default directory for downloads
"download.prompt_for_download": False, #To auto download the file
"download.directory_upgrade": True,
"plugins.always_open_pdf_externally": True #It will not show PDF directly in chrome
})


driver = webdriver.Chrome(executable_path="E:\Software\chromedriver.exe",options=options)
driver.get("http://192.168.20.159/FinUltimusSPARKTEST/")
user_ele=driver.find_element_by_name("UserId")

pass_ele=driver.find_element_by_name("PasswordString")

user_ele.send_keys("s1")
pass_ele.send_keys("1")
pass_ele=driver.find_element_by_name("PasswordString")
driver.find_element_by_id("btnlogin").click()

drp=Select(driver.find_element_by_name("ctl00$ddlMenutype"))
#driver.find_element_by_value("R").click()
drp.select_by_value("R")


#v_search2=[9309,9302,9309,9830]
path="E:selenium//result.xlsx"
df=openpyxl.load_workbook(path)
sheet=df.active
v_search2=[]
df1=df['result']
df2=df['perameter']
for i in range(1,df1.max_row+1):
    j=df1.cell(row=i,column=1)
    v_search2.append(j.value)
print(v_search2)


for x in range(len(v_search2)):
    driver.find_element_by_id("txtMenuSearch").clear()
    ser_ele=driver.find_element_by_id("txtMenuSearch")
    k=v_search2[x]
    print(k)  
    ser_ele.send_keys(k)
    ser_ele.send_keys(Keys.ENTER)
    
    table=driver.find_elements_by_tag_name('h1')
    print(len(table))
    print("")
    if(len(table)==0):
        #print("welcome")
        for i in range(2,df2.max_row+1):
            
            c=df2.cell(row=i,column=1)
            #print(i,1)
            if c.value==k:
                
                #print('ok')
                d=df2.cell(row=i,column=4)
                id_tag=df2.cell(row=i,column=3)
                e=df2.cell(row=i,column=5)
                    
                if id_tag.value=='Id':
                    
                    #print("hello")
                    acc_ele=driver.find_element_by_id(d.value)
                    acc_ele.send_keys(e.value)
                elif id_tag.value=='name':
                    acc_ele=driver.find_element_by_name(d.value)
                    acc_ele.send_keys(e.value)
                        
                        
         
        ok_ele=driver.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()
     
        action = ActionChains(driver)
 
        #perform the operation
        action.key_down(Keys.ALT).send_keys('O').perform()
       
        #ok button work...............
       
        #print(driver.window_handles[0])
       
       
       
        window_after = driver.window_handles[1]
        #print(window_after)
        driver.switch_to.window(window_after)
        
        
        #print(window_after)
   
        suc_ele=driver.find_elements_by_tag_name('body')
        fal_ele=driver.find_elements_by_tag_name('form')
            

        print(k)
        for i in range(1,df1.max_row+1):
            for j in range(1,2):
               
                if(df1.cell(i,j).value==k ):
                 
                    if len(fal_ele)==0:
                    
                        df1.cell(i,j+1).value="ok"
                       
                    else:
                        
                        df1.cell(i,j+1).value="Failed"
      
        df.save(path)
        
    
        file_exist=os.path.exists('C:\\Users\\rafiquel.islam\\Desktop\\Report File\\BU_ReportPreviewPOPUPUI.pdf')
        await asyncio.sleep(5) 
        if(file_exist==True):
            #time.sleep(1) 
            os.rename("C:\\Users\\rafiquel.islam\\Desktop\\Report File\\BU_ReportPreviewPOPUPUI.pdf",
                        "C:\\Users\\rafiquel.islam\\Desktop\\Report File\\"+str(k)+".pdf")
            await asyncio.sleep(2)
        #time.sleep(0.5)   
        print(file_exist)
        driver.close()
       
        window_before = driver.window_handles[0]
        driver.switch_to.window(window_before)
        #time.sleep(0.2) 
             
             
    else:
        for i in range(1,df1.max_row+1):
            for j in range(1,2):
               
                if(df1.cell(i,j).value==k ):
                     df1.cell(i,j+1).value="Unauthorized"
        df.save(path)       
                    
        continue
# Out:
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:20: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="E:\Software\chromedriver.exe",options=options)
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:22: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   user_ele=driver.find_element_by_name("UserId")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:24: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   pass_ele=driver.find_element_by_name("PasswordString")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:28: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   pass_ele=driver.find_element_by_name("PasswordString")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:29: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("btnlogin").click()
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:31: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   drp=Select(driver.find_element_by_name("ctl00$ddlMenutype"))
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:50: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("txtMenuSearch").clear()
# [9800, 9801, 9802, 9803, 9804, 9805, 9806, 9807, 9808, 9809, 9810, 9811, 9812, 9813, 9814, 9815, 9816, 9817, 9818, 9819, 9820, 9821, 9822, 9823, 9824, 9825, 9826, 9827, 9828, 9829, 9830]
# 9800
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:51: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ser_ele=driver.find_element_by_id("txtMenuSearch")
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:57: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   table=driver.find_elements_by_tag_name('h1')
# 1
#
# 9801
# 0
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:84: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   ok_ele=driver.find_element_by_name("ctl00$contPlcHdrMasterHolder$btnOK").click()
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:104: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   suc_ele=driver.find_elements_by_tag_name('body')
# C:\Users\rafiquel.islam\AppData\Local\Temp\ipykernel_12440\1550982685.py:105: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   fal_ele=driver.find_elements_by_tag_name('form')
# 9801
# True
# 9802
# 0
#
# 9802
